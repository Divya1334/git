# %%
s="i like python and i like ds"
words=s.split()
freq={}
for word in words:
    if word in freq:
        freq[word]+=1
    else:
        freq[word]=1
print(freq)
# Out:
# {'i': 2, 'like': 2, 'python': 1, 'and': 1, 'ds': 1}

# %%
s="i like python and i like ds"
words=s.split()
freq={}
def frequency(s):
    for word in words:
        if word in freq:
            freq[word]+=1
        else:
            freq[word]=1
    return freq
print(frequency(s))
# Out:
# {'i': 2, 'like': 2, 'python': 1, 'and': 1, 'ds': 1}
